# %% [markdown]
# <a href="https://colab.research.google.com/github/anamdias/anamdias/blob/main/TC3G.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c08d8476-d7f3-4ad9-94ce-aa462276530e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c08d8476-d7f3-4ad9-94ce-aa462276530e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a970c2ef-6620-4463-a998-bdaedba1a513" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a970c2ef-6620-4463-a998-bdaedba1a513">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# ler o dicionário de setembro
dic = pd.read_excel("Dicionario_PNAD_COVID_092020_20220621.xls")

# mostrar primeiras linhas
dic.head()
# Out:
#   Dicionário das variáveis da PNAD COVID            Unnamed: 1 Unnamed: 2  \
# 0                                Tamanho  Código\nda\nvariável    Quesito
# 1                                    NaN                   NaN         nº
# 2     Parte 1 - Identificação e Controle                   NaN        NaN
# 3                                      4                   Ano        NaN
# 4                                      2                    UF        NaN
#
#              Unnamed: 3  Unnamed: 4 Unnamed: 5
# 0                   NaN  Categorias        NaN
# 1             Descrição       Tipo   Descrição
# 2                   NaN         NaN        NaN
# 3     Ano de referência         NaN        NaN
# 4  Unidade da Federação          11   Rondônia

# %%
# ler o dicionário usando a linha 6 como cabeçalho
dic = pd.read_excel(
    "Dicionario_PNAD_COVID_092020_20220621.xls",
    header=3
)

# visualizar as primeiras linhas
dic.head()
# Out:
#      2   UF Unnamed: 2 Unidade da Federação  11  Rondônia
# 0  NaN  NaN        NaN                  NaN  12      Acre
# 1  NaN  NaN        NaN                  NaN  13  Amazonas
# 2  NaN  NaN        NaN                  NaN  14   Roraima
# 3  NaN  NaN        NaN                  NaN  15      Pará
# 4  NaN  NaN        NaN                  NaN  16     Amapá

# %%
# ler o dicionário de setembro
dic = pd.read_excel("Dicionario_PNAD_COVID_092020_20220621.xls")

# mostrar primeiras linhas
dic.head()
# Out:
#   Dicionário das variáveis da PNAD COVID            Unnamed: 1 Unnamed: 2  \
# 0                                Tamanho  Código\nda\nvariável    Quesito
# 1                                    NaN                   NaN         nº
# 2     Parte 1 - Identificação e Controle                   NaN        NaN
# 3                                      4                   Ano        NaN
# 4                                      2                    UF        NaN
#
#              Unnamed: 3  Unnamed: 4 Unnamed: 5
# 0                   NaN  Categorias        NaN
# 1             Descrição       Tipo   Descrição
# 2                   NaN         NaN        NaN
# 3     Ano de referência         NaN        NaN
# 4  Unidade da Federação          11   Rondônia

# %%
# ler o dicionário usando a linha 6 como cabeçalho
dic = pd.read_excel(
    "Dicionario_PNAD_COVID_092020_20220621.xls",
    header=2
)

# visualizar as primeiras linhas
dic.head()
# Out:
#                            Unnamed: 0 Unnamed: 1   nº             Descrição  \
# 0  Parte 1 - Identificação e Controle        NaN  NaN                   NaN
# 1                                   4        Ano  NaN     Ano de referência
# 2                                   2         UF  NaN  Unidade da Federação
# 3                                 NaN        NaN  NaN                   NaN
# 4                                 NaN        NaN  NaN                   NaN
#
#   Tipo  Descrição.1
# 0   NaN         NaN
# 1   NaN         NaN
# 2    11    Rondônia
# 3    12        Acre
# 4    13    Amazonas

# %%
dic.columns = [
    "tamanho",
    "codigo_variavel",
    "numero_valor",
    "descricao_variavel",
    "tipo",
    "descricao_valor"
]

# %%
dic.head()
# Out:
#                               tamanho codigo_variavel numero_valor  \
# 0  Parte 1 - Identificação e Controle             NaN          NaN
# 1                                   4             Ano          NaN
# 2                                   2              UF          NaN
# 3                                 NaN             NaN          NaN
# 4                                 NaN             NaN          NaN
#
#      descricao_variavel tipo descricao_valor
# 0                   NaN  NaN             NaN
# 1     Ano de referência  NaN             NaN
# 2  Unidade da Federação   11        Rondônia
# 3                   NaN   12            Acre
# 4                   NaN   13        Amazonas

# %%
dic["codigo_variavel"].unique()
# Out:
# array([nan, 'Ano', 'UF', 'CAPITAL', 'RM_RIDE', 'V1008', 'V1012', 'V1013',
#        'V1016', 'Estrato', 'UPA', 'V1022', 'V1023', 'V1030', 'V1031',
#        'V1032', 'posest', 'A001', 'A001A', 'A001B1', 'A001B2', 'A001B3',
#        'A002', 'A003', 'A004', 'A005', 'A006', 'A007', 'A008', 'A009',
#        'B0011', 'B0012', 'B0013', 'B0014', 'B0015', 'B0016', 'B0017',
#        'B0018', 'B0019', 'B00110', 'B00111', 'B00112', 'B00113', 'B002',
#        'B0031', 'B0032', 'B0033', 'B0034', 'B0035', 'B0036', 'B0037',
#        'B0041', 'B0042', 'B0043', 'B0044', 'B0045', 'B0046', 'B005',
#        'B006', 'B007', 'B008', 'B009A', 'B009B', 'B009C', 'B009D',
#        'B009E', 'B009F', 'B0101', 'B0102', 'B0103', 'B0104', 'B0105',
#        'B0106', 'B011', 'C001', 'C002', 'C003', 'C004', 'C005', 'C0051',
#        'C0052', 'C0053', 'C006', 'C007', 'C007A', 'C007B', 'C007C',
#        'C007D', 'C007E', 'C007E1', 'C007E2', 'C007F', 'C008', 'C009',
# ...

# %%
# Procurando variáveis relacionadas a sintomas

dic[dic["descricao_variavel"].str.contains("sintoma", case=False, na=False)]
# Out:
#     tamanho codigo_variavel numero_valor  \
# 213       1           B0031           B3
# 217       1           B0032           B3
# 221       1           B0033           B3
# 225       1           B0034           B3
# 229       1           B0035           B3
# 233       1           B0036           B3
# 237       1           B0037           B3
#
#                                     descricao_variavel tipo descricao_valor
# 213  Providência tomada para recuperar dos sintomas...    1             Sim
# 217  Providência tomada para recuperar dos sintomas...    1             Sim
# 221  Providência tomada  para recuperar dos sintoma...    1             Sim
# 225  Providência tomada para recuperar dos sintomas...    1             Sim
# 229  Providência tomada para recuperar dos sintomas...    1             Sim
# 233  Providência tomada para recuperar dos sintomas...    1             Sim
# 237  Providência tomada para recuperar dos sintomas...    1             Sim

# %%
# Procurando palavaras específicas

dic[dic["descricao_variavel"].str.contains("febre|tosse|resp", case=False, na=False)]
# Out:
#     tamanho codigo_variavel numero_valor  \
# 157       1           B0011           B1
# 161       1           B0012           B1
# 169       1           B0014           B1
# 270       1            B006           B6
# 313       1           B0103          B10
# 638       2           F0061          F61
#
#                                     descricao_variavel tipo  descricao_valor
# 157                      Na semana passada teve febre?    1              Sim
# 161                      Na semana passada teve tosse?    1              Sim
# 169  Na semana passada teve dificuldade para respirar?    1              Sim
# 270  Durante a internação, foi sedado, entubado e c...    1              Sim
# 313  Algum médico já lhe deu o diagnóstico de asma/...    1              Sim
# 638                    Quem respondeu ao questionário?    1  Pessoa moradora

# %%
variaveis_importantes = [
"B0011",
"B0012",
"B0013",
"B0014",
"B0015",
"B0019",
"B00110",
"B002",
"B005",
"C001",
"D001"
]

# %%
dic[dic["codigo_variavel"].isin(variaveis_importantes)][
["codigo_variavel","descricao_variavel"]
].drop_duplicates()
# Out:
#     codigo_variavel                                 descricao_variavel
# 157           B0011                      Na semana passada teve febre?
# 161           B0012                      Na semana passada teve tosse?
# 165           B0013            Na semana passada teve dor de garganta?
# 169           B0014  Na semana passada teve dificuldade para respirar?
# 173           B0015              Na semana passada teve dor de cabeça?
# 189           B0019                     Na semana passada teve fadiga?
# 193          B00110              Na semana passada teve dor nos olhos?
# 209            B002  Por causa disso, foi a algum estabelecimento d...
# 265            B005  Ao procurar o hospital, teve que ficar interna...
# 331            C001  Na semana passada, por pelo menos uma hora, tr...

# %%
# variáveis importantes escolhidas a partir do dicionário

variaveis_importantes = [
    "B0011",  # febre
    "B0012",  # tosse
    "B0013",  # dor de garganta
    "B0014",  # dificuldade respiratória
    "B0015",  # dor de cabeça
    "B0019",  # fadiga
    "B00110", # perda de olfato

    "B002",   # procurou atendimento
    "B005",   # fez teste

    "C001",   # trabalhou
    "D001"    # recebeu auxílio
]

# %%
# verificar se as colunas existem na base
[col for col in variaveis_importantes if col in df.columns]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_566/2826787537.py in <cell line: 0>()
#       1 # verificar se as colunas existem na base
# ----> 2 [col for col in variaveis_importantes if col in df.columns]
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# ler arquivo de agosto
aug = pd.read_csv("PNAD_COVID_082020.csv", sep=";", encoding="latin1")

# ler arquivo de setembro
sep = pd.read_csv("PNAD_COVID_092020.csv", sep=";", encoding="latin1")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_566/3143144621.py in <cell line: 0>()
#       2
#       3 # ler arquivo de agosto
# ----> 4 aug = pd.read_csv("PNAD_COVID_082020.csv", sep=";", encoding="latin1")
#       5
#       6 # ler arquivo de setembro
#
# ...

# %%
import os

os.listdir()
# Out:
# ['.config',
#  'Dicionario_PNAD_COVID_082020_20220621.xls',
#  'Dicionario_PNAD_COVID_092020_20220621.xls',
#  'PNAD_COVID_092020.zip',
#  'PNAD_COVID_082020.zip',
#  'sample_data']
